# %% [markdown]
# # PRINCIPAL COMPONENT ANALYSIS (PCA)
# **Developer:** Alexander Valdez Portocarrero\
# Ing. Electronico- UNI
# ### PRUEBAS Y EJEMPLOS

# %% [markdown]
# #### 1. Importando Librerias

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn import decomposition

# %%
X1,Y1 =  make_blobs(n_features=10,n_samples=100,centers=4,random_state=4,cluster_std=1)

# %%
print(X1.shape)
print(Y1.shape)
# Out:
# (100, 10)
# (100,)

# %% [markdown]
# #### 2. Creacion de Dataframe

# %%
df = pd.DataFrame(X1,index=range(X1.shape[0]),columns=range(X1.shape[1]))

# %%
print(len(df.columns))
# Out:
# 10

# %%
df
# Out:
#            0         1          2          3         4         5          6  \
# 0  -0.082804  9.802603   6.321587   7.283099 -7.020766 -9.397969   1.444042
# 1   4.754935 -5.752100   6.648462  10.020271 -5.053426  3.891982  -8.993215
# 2   9.169482  1.128930   9.052510   5.191424  2.458724 -6.373607   9.406078
# 3   0.317239  8.475311  -1.141536  -7.707184 -7.304231 -1.319467   2.386655
# 4   9.143852  1.781174  10.240289   2.455444  3.992124 -5.642282   8.746749
# ..       ...       ...        ...        ...       ...       ...        ...
# 95  9.954129  0.734488   9.861745   6.028718  3.605129 -6.911347  10.243763
# 96  3.385594 -3.259495   8.272444  10.026804 -3.946020  1.871413  -8.374345
# 97  1.877194  9.030563  -0.307766  -7.598400 -7.233577 -1.295777   0.375085
# 98  8.292622 -5.956244   7.879948  11.897879 -6.093983  2.701820  -9.992196
# 99 -0.209515  8.933594   6.407308   7.307560 -6.134533 -6.914984   1.145195
#
#             7          8         9
# 0   -6.696570   3.695892 -0.847258
# 1   -1.793329  -9.087479  9.544173
# 2  -10.920219  -4.579715 -2.819074
# 3    3.350410  -1.499193  3.148171
# 4   -9.695984  -6.395887 -0.747984
# ..        ...        ...       ...
# 95  -9.358835  -4.266551 -0.277714
# 96  -2.256114  -9.392443  9.765574
# 97   1.583794  -0.643550  3.387134
# 98  -1.793277 -10.166286  9.063513
# 99  -7.833541   5.119551 -2.412384
#
# [100 rows x 10 columns]

# %%
df['y']=Y1

# %%
print(len(df.columns))
# Out:
# 11

# %%
df
# Out:
#            0         1          2          3         4         5          6  \
# 0  -0.082804  9.802603   6.321587   7.283099 -7.020766 -9.397969   1.444042
# 1   4.754935 -5.752100   6.648462  10.020271 -5.053426  3.891982  -8.993215
# 2   9.169482  1.128930   9.052510   5.191424  2.458724 -6.373607   9.406078
# 3   0.317239  8.475311  -1.141536  -7.707184 -7.304231 -1.319467   2.386655
# 4   9.143852  1.781174  10.240289   2.455444  3.992124 -5.642282   8.746749
# ..       ...       ...        ...        ...       ...       ...        ...
# 95  9.954129  0.734488   9.861745   6.028718  3.605129 -6.911347  10.243763
# 96  3.385594 -3.259495   8.272444  10.026804 -3.946020  1.871413  -8.374345
# 97  1.877194  9.030563  -0.307766  -7.598400 -7.233577 -1.295777   0.375085
# 98  8.292622 -5.956244   7.879948  11.897879 -6.093983  2.701820  -9.992196
# 99 -0.209515  8.933594   6.407308   7.307560 -6.134533 -6.914984   1.145195
#
#             7          8         9  y
# 0   -6.696570   3.695892 -0.847258  2
# 1   -1.793329  -9.087479  9.544173  1
# 2  -10.920219  -4.579715 -2.819074  0
# 3    3.350410  -1.499193  3.148171  3
# 4   -9.695984  -6.395887 -0.747984  0
# ..        ...        ...       ... ..
# 95  -9.358835  -4.266551 -0.277714  0
# 96  -2.256114  -9.392443  9.765574  1
# 97   1.583794  -0.643550  3.387134  3
# 98  -1.793277 -10.166286  9.063513  1
# 99  -7.833541   5.119551 -2.412384  2
#
# [100 rows x 11 columns]

# %%
df.rename(columns={0:'x1',1:'x2',2:'x3',3:'x4',4:'x5',5:'x6',6:'x7',7:'x8',8:'x9',9:'x10'},inplace=True)

# %%
df
# Out:
#           x1        x2         x3         x4        x5        x6         x7  \
# 0  -0.082804  9.802603   6.321587   7.283099 -7.020766 -9.397969   1.444042
# 1   4.754935 -5.752100   6.648462  10.020271 -5.053426  3.891982  -8.993215
# 2   9.169482  1.128930   9.052510   5.191424  2.458724 -6.373607   9.406078
# 3   0.317239  8.475311  -1.141536  -7.707184 -7.304231 -1.319467   2.386655
# 4   9.143852  1.781174  10.240289   2.455444  3.992124 -5.642282   8.746749
# ..       ...       ...        ...        ...       ...       ...        ...
# 95  9.954129  0.734488   9.861745   6.028718  3.605129 -6.911347  10.243763
# 96  3.385594 -3.259495   8.272444  10.026804 -3.946020  1.871413  -8.374345
# 97  1.877194  9.030563  -0.307766  -7.598400 -7.233577 -1.295777   0.375085
# 98  8.292622 -5.956244   7.879948  11.897879 -6.093983  2.701820  -9.992196
# 99 -0.209515  8.933594   6.407308   7.307560 -6.134533 -6.914984   1.145195
#
#            x8         x9       x10  y
# 0   -6.696570   3.695892 -0.847258  2
# 1   -1.793329  -9.087479  9.544173  1
# 2  -10.920219  -4.579715 -2.819074  0
# 3    3.350410  -1.499193  3.148171  3
# 4   -9.695984  -6.395887 -0.747984  0
# ..        ...        ...       ... ..
# 95  -9.358835  -4.266551 -0.277714  0
# 96  -2.256114  -9.392443  9.765574  1
# 97   1.583794  -0.643550  3.387134  3
# 98  -1.793277 -10.166286  9.063513  1
# 99  -7.833541   5.119551 -2.412384  2
#
# [100 rows x 11 columns]

# %%
print(df.columns)
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'y'], dtype='object')

# %% [markdown]
# LMPLOT dispersion o scatter

# %%
sns.lmplot(x='x2',y='x3',data=df,fit_reg=False,hue='y',legend=True,scatter_kws={"s":80})

# %%
pca = decomposition.PCA(n_components=4)
pc  = pca.fit_transform(X1)

# %%
df =pd.DataFrame({'var': pca.explained_variance_ratio_,'PC':['PC1','PC2','PC3','PC4']})

# %%
df
# Out:
#         var   PC
# 0  0.445205  PC1
# 1  0.362620  PC2
# 2  0.169061  PC3
# 3  0.005475  PC4

# %%
plt.figure()
sns.barplot(x='PC',y='var',data=df,color='c')
# Out:
# <Axes: xlabel='PC', ylabel='var'>

# %%
pc_df = pd.DataFrame(data=pc,columns=['PC1','PC2','PC3','PC4'])
pc_df['Cluster']=Y1

# %%
sns.lmplot(x='PC1',y='PC2',
           data=pc_df,
           fit_reg=False,
           hue='Cluster',#Color by cluster
           legend=True,
           scatter_kws={'s':80})
plt.show()
